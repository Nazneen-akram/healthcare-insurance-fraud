# %% [markdown]
# <a href="https://colab.research.google.com/github/Nazneen-akram/healthcare-insurance-fraud/blob/main/EDA_health_insurance_V1_02JAN2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the datasets
data_paths = {
    "inpatient_train_data": "Train_Inpatientdata-1542865627584.csv",
    "outpatient_train_data": "Train_Outpatientdata-1542865627584.csv",
    "beneficiary_train_data": "Train_Beneficiarydata-1542865627584.csv",
    "provider_train_data": "Train-1542865627584.csv",
    "inpatient_test_data": "Test_Inpatientdata-1542969243754.csv",
    "outpatient_test_data": "Test_Outpatientdata-1542969243754.csv",
    "beneficiary_test_data": "Test_Beneficiarydata-1542969243754.csv",
    "provider_test_data": "Test-1542969243754.csv",
}

# %%
# Load datasets into a dictionary of dataframes
dataframes = {}
for key, value in data_paths.items():
    try:
        dataframes[key] = pd.read_csv(value, on_bad_lines='skip', delimiter=',')
    except pd.errors.ParserError:
        print(f"Error parsing {value}. Please check the file format.")

# %%
# Perform EDA on each dataset
for dataset_name, df in dataframes.items():
    print(f"Exploring {dataset_name} Dataset")
    # Basic information about the dataset
    df.info()

    # Descriptive statistics for numerical features
    #df.describe()
# Out:
# Exploring inpatient_train_data Dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40474 entries, 0 to 40473
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   BeneID                  40474 non-null  object
#  1   ClaimID                 40474 non-null  object
#  2   ClaimStartDt            40474 non-null  object
#  3   ClaimEndDt              40474 non-null  object
#  4   Provider                40474 non-null  object
#  5   InscClaimAmtReimbursed  40474 non-null  int64
#  6   AttendingPhysician      40362 non-null  object
#  7   OperatingPhysician      23830 non-null  object
#  8   OtherPhysician          4690 non-null   object
#  9   AdmissionDt             40474 non-null  object
#  10  ClmAdmitDiagnosisCode   40474 non-null  object
#  11  DeductibleAmtPaid       39575 non-null  float64
#  12  DischargeDt             40474 non-null  object
# ...
